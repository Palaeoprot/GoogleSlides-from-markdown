# %% [markdown]
# <a href="https://colab.research.google.com/github/Palaeoprot/GoogleSlides-from0markdown/blob/main/GoogleSlides_md_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cell 1 – Project Overview
# # Google Slides Markdown to Presentation Converter
#
# ## Requirements
# This script converts a Markdown file into a Google Slides presentation using a predefined slide template.
#
# ### Formatting Requirements:
# 1. The presentation must use the custom template from `PalaeomeSlideFormat.pptx`.
# 2. The **Lato** font must be applied to all text fields (title and body).
# 3. Slide types and layouts must follow these rules:
#    - The **first slide** uses the "Title" layout from the template.
#    - All subsequent content slides use the "Title and Content" layout.
#    - Any section dividers should use the "Section Header" layout.
# 4. Use proper `placeholderIdMappings` to bind content to TITLE and BODY placeholders.
# 5. If needed, explicitly enforce Lato font using `updateTextStyle` with `"fontFamily": "Lato"`.
#
# Ensure that the template ID (`template_id`) is correctly set for the PalaeomeSlideFormat in Google Drive.

# %% [markdown]
# # Markdown Formatting Guide for Google Slides Converter
#
# ## Overview
# This guide explains the exact formatting requirements for markdown files that will be converted to Google Slides presentations using the Python converter.
#
# ## File Structure
# - Use **YAML-style frontmatter** with sections separated by `---` (three dashes)
# - Each section between separators represents **one slide**
# - Sections must be separated by exactly `---` on its own line
# - Empty sections are automatically skipped
#
# ## Required Fields for Each Slide
#
# ### Universal Fields
# - `layout:` - Determines slide type (required)
# - `title:` - Slide title (required)
#
# ### Optional Fields
# - `subtitle:` - Subtitle for title and section slides
# - `presenter:` - Presenter name (title slides only)
# - `body:` - Main content (content slides only)
#
# ## Slide Layout Types
#
# ### 1. Title Slide (`layout: title`)
# ```markdown
# layout: title
# title: Your Presentation Title
# subtitle: Optional Subtitle Here
# presenter: Your Name
# ---
# ```
#
# ### 2. Section Header (`layout: section_header`)
# ```markdown
# layout: section_header
# title: Section Name
# subtitle: Optional Section Description
# ---
# ```
#
# ### 3. Content Slide (`layout: content`)
# ```markdown
# layout: content
# title: Slide Title
# body: |
#   * First bullet point
#   * Second bullet point
#   * Third bullet point
# ---
# ```
#
# ## Body Content Formatting Rules
#
# ### Multi-line Content (Recommended)
# Always use the pipe (`|`) syntax for body content:
# ```markdown
# body: |
#   Line 1 of content
#   Line 2 of content
#   Line 3 of content
# ```
#
# ### Indentation Rules
# - **CRITICAL:** All body content lines must be indented with exactly **2 spaces**
# - The parser removes the first 2 spaces from each line
# - Additional indentation beyond 2 spaces creates nested content
#
# ```markdown
# body: |
#   * Top-level bullet (2 spaces)
#     * Sub-bullet (4 spaces = 2 removed + 2 kept)
#       * Sub-sub-bullet (6 spaces = 2 removed + 4 kept)
# ```
#
# ### Bullet Points
# Use asterisks (`*`) or dashes (`-`) for bullets:
# ```markdown
# body: |
#   * Primary bullet point
#   * Another primary bullet
#     * Nested sub-bullet
#     * Another sub-bullet
#   * Back to primary level
# ```
#
# ### Text Formatting
# Standard markdown formatting within content:
# ```markdown
# body: |
#   * **Bold text** for emphasis
#   * *Italic text* for subtle emphasis
#   * `Code or technical terms`
#   * Regular text for normal content
# ```
#
# ### Paragraph Breaks
# Use empty lines for paragraph separation:
# ```markdown
# body: |
#   * First paragraph of bullets
#   * More bullets in first paragraph
#
#   * Second paragraph starts here
#   * More content in second paragraph
# ```
#
# ## Complete Example Template
#
# ```markdown
# layout: title
# title: My Presentation Title
# subtitle: A Comprehensive Overview
# presenter: Your Name
# ---
# layout: section_header
# title: Introduction
# subtitle: Setting the Context
# ---
# layout: content
# title: Key Concepts
# body: |
#   * **First concept:** Brief explanation here
#   * **Second concept:** Building on the first
#     * Supporting detail A
#     * Supporting detail B
#   * **Third concept:** Bringing it all together
# ---
# layout: content
# title: Detailed Analysis
# body: |
#   The research reveals several important findings:
#
#   * **Finding 1:** Significant results observed
#   * **Finding 2:** Unexpected patterns emerged
#   * **Finding 3:** Hypothesis confirmed
#
#   These results suggest new directions for future work.
# ---
# layout: section_header
# title: Conclusion
# ---
# layout: content
# title: Summary
# body: |
#   * We have successfully demonstrated our approach
#   * Key contributions include methodology and findings
#   * Future work should expand the scope
#   * Thank you for your attention
# ---
# ```
#
# ## Critical Formatting Rules
#
# ### ✅ DO:
# - Use exactly `---` (three dashes) as separators
# - Indent body content with exactly 2 spaces
# - Use consistent field names: `layout:`, `title:`, `subtitle:`, `body:`
# - Include `body: |` for multi-line content
# - Use standard markdown formatting (`**bold**`, `*italic*`)
#
# ### ❌ DON'T:
# - Use tabs instead of spaces for indentation
# - Forget the `|` after `body:`
# - Use inconsistent spacing
# - Include extra characters in separators (like `----` or `--- `)
# - Mix indentation styles within the same file
#
# ## Common Mistakes to Avoid
#
# 1. **Wrong separator:** Using `----` instead of `---`
# 2. **Missing pipe:** Writing `body:` instead of `body: |`
# 3. **Incorrect indentation:** Using tabs or wrong number of spaces
# 4. **Inconsistent field names:** Using `Body:` instead of `body:`
# 5. **Missing separators:** Forgetting `---` between slides
#
# ## Validation Checklist
#
# Before running the converter, verify:
# - [ ] Each slide section is separated by `---`
# - [ ] All body content uses `body: |` format
# - [ ] All body content lines start with exactly 2 spaces
# - [ ] Layout types are spelled correctly: `title`, `section_header`, or `content`
# - [ ] No trailing spaces after field names or separators
# - [ ] File encoding is UTF-8
#
# ## Field Defaults
#
# If fields are missing, the parser uses these defaults:
# - **layout:** Defaults to `content`
# - **title:** Defaults to "Untitled Slide"
# - **subtitle:** Defaults to empty string
# - **body:** Defaults to empty list
#
# Following these formatting rules ensures your markdown file will convert correctly to a Google Slides presentation with proper layout, formatting, and content structure.

# %%
# ===== Cell 2 =====
# Authentication and Google Drive connection
from google.colab import auth, drive
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import os
import traceback
import time
import re
import yaml

# Mount Google Drive
drive.mount('/content/drive')

# Authenticate using Colab's built-in method
auth.authenticate_user()

# Build the Google Slides service
slides_service = build('slides', 'v1')
# Out:
# Mounted at /content/drive

# %%
# ===== Cell 3 =====
# Configuration parameters
md_path = "/content/test2_deduped.md" #@param {type:"string"}
save_folder = "/content/drive/MyDrive/4 Presentations/Python Presentations/" #@param {type:"string"}
template_id = "1bYjQ10Pfkjk16ATPJlXL9xy-MxkR9JQVgF41pEZPMHg" #@param {type:"string"}
presentation_name = "Parchment2.md" #@param {type:"string"}
debug_mode = False #@param {type:"boolean"}
default_font = "Lato Light" #@param {type:"string"}

# %%
# ===== Cell 4 =====
# Helper functions for folder and layout management
def get_or_create_folder(service, folder_path):
    """Creates folder structure in Google Drive if it doesn't exist."""
    relative_path = folder_path.replace('/content/drive/MyDrive/', '')
    parts = relative_path.strip('/').split('/')
    parent_id = 'root'

    for part in parts:
        query = (
            f"name='{part}' and mimeType='application/vnd.google-apps.folder' "
            f"and '{parent_id}' in parents and trashed=false"
        )
        result = service.files().list(q=query, spaces='drive', fields='files(id, name)').execute().get('files', [])
        if result:
            parent_id = result[0]['id']
        else:
            folder_metadata = {
                'name': part,
                'mimeType': 'application/vnd.google-apps.folder',
                'parents': [parent_id]
            }
            folder = service.files().create(body=folder_metadata, fields='id').execute()
            parent_id = folder['id']
    return parent_id

def get_layout_id_by_name(presentation_info, layout_name):
    """Finds the layout ID based on its name."""
    layout_mapping = {
        'title': 'TITLE',
        'section_header': 'SECTION_HEADER',
        'content': 'TITLE_AND_BODY'
    }

    target_layout = layout_mapping.get(layout_name.lower(), 'TITLE_AND_BODY')

    for layout in presentation_info.get('layouts', []):
        if layout['layoutProperties']['name'].upper() == target_layout.upper():
            return layout['objectId']
    return None

def print_layouts(presentation_id):
    """Debug function to print all available layouts in the template."""
    slides_service = build('slides', 'v1')
    presentation = slides_service.presentations().get(presentationId=presentation_id).execute()
    print("Available layouts:")
    for layout in presentation.get('layouts', []):
        layout_name = layout['layoutProperties']['name']
        layout_id = layout['objectId']
        print(f"Layout Name: {layout_name}, Layout ID: {layout_id}")
        for placeholder in layout.get('placeholder', []):
            print(f" - Placeholder Type: {placeholder['type']}, ID: {placeholder['objectId']}")

# Print available layouts for debugging
print_layouts(template_id)
# Out:
# Available layouts:
# Layout Name: TITLE, Layout ID: g502d8d1410_0_4
# Layout Name: TITLE_1, Layout ID: g327232ccb0d_1_3
# Layout Name: TITLE_AND_BODY, Layout ID: g502d8d1410_0_7
# Layout Name: TITLE_ONLY, Layout ID: g502d8d1410_0_16
# Layout Name: BLANK, Layout ID: g502d8d1410_0_19
# Layout Name: BLANK_1, Layout ID: g502d8d1410_0_21

# %%
# ===== Cell 5 (Updated) - Clean Text Processing =====
# Clean text processing functions that remove all markdown formatting

def clean_markdown_text(text):
    """
    Removes all markdown formatting and returns clean plain text.
    Converts bullets to proper bullet points and removes bold/italic markers.
    """
    lines = text.split('\n')
    processed_lines = []

    for line in lines:
        # Skip empty lines
        if not line.strip():
            processed_lines.append('')
            continue

        # Handle bullet points
        if line.strip().startswith('* '):
            # Calculate indentation level
            indent_level = (len(line) - len(line.lstrip())) // 2
            # Remove the * and clean the text
            clean_text = line.strip()[2:].strip()
            # Remove bold markers
            clean_text = clean_text.replace('**', '')
            # Add proper bullet with indentation
            bullet_char = '• ' if indent_level == 0 else '  ◦ ' if indent_level == 1 else '    ▪ '
            processed_lines.append(' ' * (indent_level * 2) + bullet_char + clean_text)

        elif line.strip().startswith('- '):
            # Handle dash bullets
            indent_level = (len(line) - len(line.lstrip())) // 2
            clean_text = line.strip()[2:].strip()
            clean_text = clean_text.replace('**', '')
            bullet_char = '• ' if indent_level == 0 else '  ◦ ' if indent_level == 1 else '    ▪ '
            processed_lines.append(' ' * (indent_level * 2) + bullet_char + clean_text)

        else:
            # Regular text line - just remove markdown formatting
            clean_text = line.replace('**', '').replace('*', '').replace('_', '')
            processed_lines.append(clean_text)

    return '\n'.join(processed_lines)

def get_placeholder_ids(slides_service, presentation_id, slide_id):
    """Fetches placeholder IDs (e.g., TITLE, BODY) from a newly created slide."""
    try:
        presentation = slides_service.presentations().get(presentationId=presentation_id).execute()
        for slide in presentation['slides']:
            if slide['objectId'] == slide_id:
                print(f"\n🔍 Slide ID: {slide_id}")
                placeholders = {}
                for element in slide.get('pageElements', []):
                    if 'shape' in element and 'placeholder' in element['shape']:
                        ph_info = element['shape']['placeholder']
                        ph_type = ph_info.get('type', 'UNKNOWN')
                        ph_id = element['objectId']
                        placeholders[ph_type] = ph_id
                        print(f" - Found placeholder: Type={ph_type}, Object ID={ph_id}")
                return placeholders
        print(f"⚠️ No placeholders found for slide {slide_id}")
        return {}
    except Exception as e:
        print(f"Error fetching placeholders: {e}")
        traceback.print_exc()
        return {}

def create_slide_presentation(slides_content, folder_path, template_id, presentation_name, debug=False):
    """Creates a Google Slides presentation from parsed markdown content with clean text."""
    slides_service = build('slides', 'v1')
    drive_service = build('drive', 'v3')

    # Copy template to new presentation
    folder_id = get_or_create_folder(drive_service, folder_path)
    copied_file = {'name': presentation_name, 'parents': [folder_id]}
    presentation = drive_service.files().copy(fileId=template_id, body=copied_file).execute()
    presentation_id = presentation['id']

    # Get layout info from template
    template_info = slides_service.presentations().get(presentationId=template_id).execute()

    # Remove all initial slides
    presentation_info = slides_service.presentations().get(presentationId=presentation_id).execute()
    requests = []
    for slide in presentation_info.get('slides', []):
        requests.append({'deleteObject': {'objectId': slide['objectId']}})

    if requests:
        slides_service.presentations().batchUpdate(
            presentationId=presentation_id,
            body={'requests': requests}
        ).execute()

    # Now add new slides one by one
    requests = []

    for i, slide_data in enumerate(slides_content):
        sid = f"slide_{i}"

        # Determine layout ID based on slide's layout type
        layout_id = get_layout_id_by_name(template_info, slide_data['layout'])
        if not layout_id:
            print(f"Warning: Layout '{slide_data['layout']}' not found. Using default.")
            layout_id = get_layout_id_by_name(template_info, 'content')

        # Create slide request
        requests.append({
            'createSlide': {
                'objectId': sid,
                'slideLayoutReference': {'layoutId': layout_id}
            }
        })

    # Execute batch update to create slides
    slides_service.presentations().batchUpdate(
        presentationId=presentation_id,
        body={'requests': requests}
    ).execute()

    # Now fetch presentation again and insert clean text
    requests = []

    for i, slide_data in enumerate(slides_content):
      try:
        sid = f"slide_{i}"
        placeholders = get_placeholder_ids(slides_service, presentation_id, sid)

        # Try common title placeholder types
        title_id = None
        for t in ['TITLE', 'CENTER_TITLE', 'SUBTITLE']:
            if t in placeholders:
                title_id = placeholders[t]
                break

        # Try common body placeholder types
        body_id = None
        for b in ['BODY', 'TEXT']:
            if b in placeholders:
                body_id = placeholders[b]

        if title_id:
            # Clean title text
            clean_title = slide_data['title'].replace('**', '').replace('*', '')
            print(f"Inserting title: {clean_title} into {title_id}")
            requests.append({'insertText': {'objectId': title_id, 'text': clean_title}})
        else:
            print("⚠️ No title placeholder found.")

        if body_id and slide_data.get('content'):
            # Clean and process body content
            raw_body_text = '\n'.join(slide_data['content'])
            clean_body_text = clean_markdown_text(raw_body_text)

            print(f"📝 Processed content preview: {clean_body_text[:100]}...")
            requests.append({'insertText': {'objectId': body_id, 'text': clean_body_text}})

        # Handle subtitle for title slides
        subtitle_id = placeholders.get('SUBTITLE')
        if subtitle_id and slide_data.get('subtitle'):
            clean_subtitle = slide_data['subtitle'].replace('**', '').replace('*', '')
            requests.append({'insertText': {'objectId': subtitle_id, 'text': clean_subtitle}})

      except Exception as e:
        print(f"Error processing slide {i+1}: {e}")
        continue

    # Send insert text requests in batches
    print(f"📝 Inserting clean text content...")
    for i in range(0, len(requests), 50):
        slides_service.presentations().batchUpdate(
            presentationId=presentation_id,
            body={'requests': requests[i:i + 50]}
        ).execute()

    print(f"✅ Presentation created: https://docs.google.com/presentation/d/{presentation_id}")
    return presentation_id

# %%
# ===== Cell 6 =====
# Enhanced markdown parser for YAML-style frontmatter
def parse_markdown_to_slides(md_path, debug=False):
    """
    Parses markdown file with YAML-style frontmatter separated by ---.
    Handles layout, title, subtitle, and body fields.
    """
    try:
        with open(md_path, 'r', encoding='utf-8') as f:
            content = f.read()
    except Exception as e:
        print(f"Error reading markdown file: {e}")
        return []

    slides = []

    # Split content by --- separators
    sections = content.split('---')

    # Remove empty sections and strip whitespace
    sections = [section.strip() for section in sections if section.strip()]

    for i, section in enumerate(sections):
        if not section:
            continue

        slide_data = {
            'layout': 'content',  # Default layout
            'title': 'Untitled Slide',
            'subtitle': '',
            'content': []
        }

        lines = section.split('\n')
        current_field = None
        body_content = []

        for line in lines:
            line = line.strip()

            if line.startswith('layout:'):
                slide_data['layout'] = line.split(':', 1)[1].strip()
            elif line.startswith('title:'):
                slide_data['title'] = line.split(':', 1)[1].strip()
            elif line.startswith('subtitle:'):
                slide_data['subtitle'] = line.split(':', 1)[1].strip()
            elif line.startswith('presenter:'):
                # Handle presenter field (could be part of title slide)
                slide_data['presenter'] = line.split(':', 1)[1].strip()
            elif line.startswith('body:'):
                current_field = 'body'
                # Check if there's content on the same line after "body:"
                body_part = line.split(':', 1)[1].strip()
                if body_part and body_part != '|':
                    body_content.append(body_part)
            elif current_field == 'body' and line:
                # Continue collecting body content
                # Remove leading spaces for proper formatting
                if line.startswith('  '):
                    line = line[2:]
                body_content.append(line)

        # Set the body content
        slide_data['content'] = body_content

        # Only add slides that have meaningful content
        if slide_data['title'] != 'Untitled Slide' or slide_data['content']:
            slides.append(slide_data)

    if debug:
        print(f"Parsed {len(slides)} slides:")
        for i, slide in enumerate(slides):
            print(f"Slide {i+1}: '{slide['title']}' (Layout: {slide['layout']})")
            if slide.get('subtitle'):
                print(f"  Subtitle: {slide['subtitle']}")
            print(f"  Content lines: {len(slide['content'])}")
            if slide['content']:
                print(f"  First content line: {slide['content'][0][:50]}...")

    return slides

# %%
# ===== Cell 7 =====
# Execute the conversion process
print("🚀 Starting markdown to slides conversion...")

# Parse the markdown file
slides = parse_markdown_to_slides(md_path, debug=debug_mode)

if slides:
    print(f"📄 Found {len(slides)} slides in the markdown file:")
    for i, slide in enumerate(slides):
        print(f"  Slide {i+1}: '{slide['title']}' (Layout: {slide['layout']})")
        if slide.get('subtitle'):
            print(f"    Subtitle: {slide['subtitle']}")
        print(f"    Content lines: {len(slide['content'])}")

    print(f"\n🔧 Creating presentation from template...")

    # Create the presentation
    presentation_id = create_slide_presentation(
        slides,
        folder_path=save_folder,
        template_id=template_id,
        presentation_name=presentation_name,
        debug=debug_mode
    )

    print(f"\n🎉 SUCCESS! Presentation created successfully!")
    print(f"📎 Direct link: https://docs.google.com/presentation/d/{presentation_id}")

else:
    print("❌ ERROR: No slides found in markdown file. Check your markdown formatting.")
# Out:
# 🚀 Starting markdown to slides conversion...
# 📄 Found 35 slides in the markdown file:
#   Slide 1: 'From Beast to Book' (Layout: title)
#     Subtitle: Biocodicology at the Crossroads of Science and the Humanities
#     Content lines: 0
#   Slide 2: 'Acknowledgements & Collaborators' (Layout: content)
#     Content lines: 3
#   Slide 3: 'Introduction' (Layout: section_header)
#     Subtitle: The Promise & Premise of Biocodicology
#     Content lines: 0
#   Slide 4: 'The Central Challenge' (Layout: content)
#     Content lines: 6
#   Slide 5: 'Promise vs. Delivery' (Layout: content)
#     Content lines: 4
#   Slide 6: 'A Success Story: A Shift in the Field' (Layout: content)
#     Content lines: 3
#   Slide 7: 'What This Talk Will Cover' (Layout: content)
#     Content lines: 4
#   Slide 8: 'Part 1' (Layout: section_header)
#     Subtitle: The Manuscript as a Biological Object
#     Content lines: 0
#   Slide 9: 'Visual Analysis: What the Eye Can See' (Layout: content)
#     Content lines: 4
#   Slide 10: 'A Vast, Untapped Zooarchaeological Archive' (Layout: content)
#     Content lines: 3
#   Slide 11: 'The Actors in Our Story' (Layout: content)
#     Content lines: 4
#   Slide 12: 'Part 2' (Layout: section_header)
#     Subtitle: In the Kitchen – New Methods & Recipes
#     Content lines: 0
#   Slide 13: 'The Sampling Problem' (Layout: content)
#     Content lines: 2
#   Slide 14: 'The Solution: Non-Invasive Sampling (eZooMS)' (Layout: content)
#     Content lines: 3
#   Slide 15: 'Recipe 1: Protein Fingerprinting (ZooMS)' (Layout: content)
#     Content lines: 3
#   Slide 16: 'Recipe 2: Measuring Quality (PQI)' (Layout: content)
#     Content lines: 3
#   Slide 17: 'Recipe 3: DNA Analysis' (Layout: content)
#     Content lines: 6
#   Slide 18: 'Summary of Methods' (Layout: content)
#     Content lines: 8
#   Slide 19: 'Part 3' (Layout: section_header)
#     Subtitle: The Big Picture – Reconstructing Medieval Economies
#     Content lines: 0
#   Slide 20: 'The Power of Scale: The 10,000 Sample Project' (Layout: content)
#     Content lines: 2
#   Slide 21: 'Regional Species Preferences' (Layout: content)
#     Content lines: 3
#   Slide 22: 'Italy's Goat Paradox' (Layout: content)
#     Content lines: 3
#   Slide 23: 'Decline in Quality Over Time' (Layout: content)
#     Content lines: 6
#   Slide 24: 'Case Studies in Animal Health' (Layout: content)
#     Content lines: 2
#   Slide 25: 'Part 4' (Layout: section_header)
#     Subtitle: The Future – Crazy Ideas & Grand Challenges
#     Content lines: 0
#   Slide 26: 'Grand Challenge 1: Genomic Stematology' (Layout: content)
#     Content lines: 3
#   Slide 27: 'Grand Challenge 2: Human DNA' (Layout: content)
#     Content lines: 2
#   Slide 28: 'Grand Challenge 3: Pathogen Archive' (Layout: content)
#     Content lines: 2
#   Slide 29: 'Grand Challenge 4: Isotopic Landscapes' (Layout: content)
#     Content lines: 2
#   Slide 30: 'Grand Challenge 5: Reading the Epigenetic Clock' (Layout: content)
#     Content lines: 2
#   Slide 31: 'The "Three Cultures"' (Layout: content)
#     Content lines: 3
#   Slide 32: 'Conclusion' (Layout: section_header)
#     Content lines: 0
#   Slide 33: 'From Beast to Book' (Layout: content)
#     Content lines: 3
#   Slide 34: 'The Path Forward' (Layout: content)
#     Content lines: 3
#   Slide 35: 'Thank You' (Layout: content)
#     Content lines: 3
#
# 🔧 Creating presentation from template...
# Warning: Layout 'section_header' not found. Using default.
# Warning: Layout 'section_header' not found. Using default.
# Warning: Layout 'section_header' not found. Using default.
# Warning: Layout 'section_header' not found. Using default.
# Warning: Layout 'section_header' not found. Using default.
# Warning: Layout 'section_header' not found. Using default.
#
# 🔍 Slide ID: slide_0
#  - Found placeholder: Type=CENTERED_TITLE, Object ID=SLIDES_API1244585020_0
#  - Found placeholder: Type=SUBTITLE, Object ID=SLIDES_API1244585020_1
# Inserting title: From Beast to Book into SLIDES_API1244585020_1
#
# 🔍 Slide ID: slide_1
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_4
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_5
# Inserting title: Acknowledgements & Collaborators into SLIDES_API1244585020_4
# 📝 Processed content preview: • This work is the result of a massive collaborative effort between scientists, humanities scholars,...
#
# 🔍 Slide ID: slide_2
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_8
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_9
# Inserting title: Introduction into SLIDES_API1244585020_8
#
# 🔍 Slide ID: slide_3
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_12
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_13
# Inserting title: The Central Challenge into SLIDES_API1244585020_12
# 📝 Processed content preview: • How do we create effective teams with people from different fields, like archaeology and computer ...
#
# 🔍 Slide ID: slide_4
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_16
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_17
# Inserting title: Promise vs. Delivery into SLIDES_API1244585020_16
# 📝 Processed content preview: • What is the career ecology of biocodicology?
# • How much is the promise, and how much is delivery?
# ...
#
# 🔍 Slide ID: slide_5
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_20
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_21
# Inserting title: A Success Story: A Shift in the Field into SLIDES_API1244585020_20
# 📝 Processed content preview: • Projects are moving from being scientist-led to being led by book historians and medieval scholars...
#
# 🔍 Slide ID: slide_6
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_24
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_25
# Inserting title: What This Talk Will Cover into SLIDES_API1244585020_24
# 📝 Processed content preview: • Part 1: The Manuscript as a Biological Object
# • Part 2: In the Kitchen – New Methods & Recipes
# • P...
#
# 🔍 Slide ID: slide_7
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_28
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_29
# Inserting title: Part 1 into SLIDES_API1244585020_28
#
# 🔍 Slide ID: slide_8
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_32
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_33
# Inserting title: Visual Analysis: What the Eye Can See into SLIDES_API1244585020_32
# 📝 Processed content preview: • Every manuscript is a stack of animal parts, rich with physical evidence.
# • Evidence of the Animal...
#
# 🔍 Slide ID: slide_9
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_36
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_37
# Inserting title: A Vast, Untapped Zooarchaeological Archive into SLIDES_API1244585020_36
# 📝 Processed content preview: • Parchment is a curated biological record, complementing bone assemblages.
# • Example: Codex Amiatin...
#
# 🔍 Slide ID: slide_10
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_40
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_41
# Inserting title: The Actors in Our Story into SLIDES_API1244585020_40
# 📝 Processed content preview: • Understanding parchment requires considering three groups:
# • The Farmer: manages livestock.
# • The ...
#
# 🔍 Slide ID: slide_11
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_44
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_45
# Inserting title: Part 2 into SLIDES_API1244585020_44
#
# 🔍 Slide ID: slide_12
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_48
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_49
# Inserting title: The Sampling Problem into SLIDES_API1244585020_48
# 📝 Processed content preview: • Challenge: accessing biological information without damaging manuscripts.
# • Destructive sampling l...
#
# 🔍 Slide ID: slide_13
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_52
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_53
# Inserting title: The Solution: Non-Invasive Sampling (eZooMS) into SLIDES_API1244585020_52
# 📝 Processed content preview: • A simple PVC eraser, standard in conservation, collects protein and DNA.
# • Eraser crumbs ("erdu") ...
#
# 🔍 Slide ID: slide_14
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_56
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_57
# Inserting title: Recipe 1: Protein Fingerprinting (ZooMS) into SLIDES_API1244585020_56
# 📝 Processed content preview: • ZooMS = Zooarchaeology by Mass Spectrometry.
# • Digestion of collagen peptides + MALDI-TOF analysis...
#
# 🔍 Slide ID: slide_15
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_60
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_61
# Inserting title: Recipe 2: Measuring Quality (PQI) into SLIDES_API1244585020_60
# 📝 Processed content preview: • Parchment Quality Index (PQI) quantifies collagen damage.
# • Lime baths (Ca(OH)₂) cause deamidation...
#
# 🔍 Slide ID: slide_16
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_64
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_65
# Inserting title: Recipe 3: DNA Analysis into SLIDES_API1244585020_64
# 📝 Processed content preview: • Ancient DNA from eraser crumbs provides:
# • Sex of the animal.
# • Genetic origin ("DNA postcoding")....
#
# 🔍 Slide ID: slide_17
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_68
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_69
# Inserting title: Summary of Methods into SLIDES_API1244585020_68
# 📝 Processed content preview: • Proteins (ZooMS & PQI):
# • Cost: low (~€50/sample)
# • Time: fast (24–48 hours)
# • Info: species ID, p...
#
# 🔍 Slide ID: slide_18
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_72
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_73
# Inserting title: Part 3 into SLIDES_API1244585020_72
#
# 🔍 Slide ID: slide_19
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_76
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_77
# Inserting title: The Power of Scale: The 10,000 Sample Project into SLIDES_API1244585020_76
# 📝 Processed content preview: • >10,000 parchment samples analysed across Europe.
# • Enables regional and temporal economic reconst...
#
# 🔍 Slide ID: slide_20
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_80
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_81
# Inserting title: Regional Species Preferences into SLIDES_API1244585020_80
# 📝 Processed content preview: • England & Spain: sheepskin → wool economies.
# • France: calfskin → dairy economy & Paris Bibles.
# • ...
#
# 🔍 Slide ID: slide_21
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_84
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_85
# Inserting title: Italy's Goat Paradox into SLIDES_API1244585020_84
# 📝 Processed content preview: • Sheep outnumber goats archaeologically in Italy.
# • Yet goatskin dominates parchment, especially in...
#
# 🔍 Slide ID: slide_22
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_88
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_89
# Inserting title: Decline in Quality Over Time into SLIDES_API1244585020_88
# 📝 Processed content preview: • PQI shows consistent decline in sheepskin quality (13th–16th C).
# • Likely drivers:
# • Commercialisa...
#
# 🔍 Slide ID: slide_23
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_92
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_93
# Inserting title: Case Studies in Animal Health into SLIDES_API1244585020_92
# 📝 Processed content preview: • Great Bovine Pestilence (1319–20): Rinderpest killed ~63% of cattle in England; skins useless.
# • S...
#
# 🔍 Slide ID: slide_24
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_96
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_97
# Inserting title: Part 4 into SLIDES_API1244585020_96
#
# 🔍 Slide ID: slide_25
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_100
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_101
# Inserting title: Grand Challenge 1: Genomic Stematology into SLIDES_API1244585020_100
# 📝 Processed content preview: • Traditional stemmatology: traces text relationships via scribal errors.
# • Genomic stemmatology: ev...
#
# 🔍 Slide ID: slide_26
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_104
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_105
# Inserting title: Grand Challenge 2: Human DNA into SLIDES_API1244585020_104
# 📝 Processed content preview: • Parchment also carries human DNA from scribes, readers, and users.
# • Example: York Gospels may hol...
#
# 🔍 Slide ID: slide_27
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_108
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_109
# Inserting title: Grand Challenge 3: Pathogen Archive into SLIDES_API1244585020_108
# 📝 Processed content preview: • Parchment may contain ancient pathogen DNA.
# • Could reconstruct histories of diseases like rinderp...
#
# 🔍 Slide ID: slide_28
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_112
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_113
# Inserting title: Grand Challenge 4: Isotopic Landscapes into SLIDES_API1244585020_112
# 📝 Processed content preview: • Stable isotopes (C, N, H) record diet and climate.
# • Pilot study: Tambora eruption (1815) signal d...
#
# 🔍 Slide ID: slide_29
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_116
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_117
# Inserting title: Grand Challenge 5: Reading the Epigenetic Clock into SLIDES_API1244585020_116
# 📝 Processed content preview: • Epigenetic markers on DNA may reveal age-at-death of animals.
# • Provides insights into herd manage...
#
# 🔍 Slide ID: slide_30
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_120
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_121
# Inserting title: The "Three Cultures" into SLIDES_API1244585020_120
# 📝 Processed content preview: • Biocodicology bridges C.P. Snow's "Two Cultures" (science & humanities).
# • Adds a third: Craft (pa...
#
# 🔍 Slide ID: slide_31
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_124
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_125
# Inserting title: Conclusion into SLIDES_API1244585020_124
#
# 🔍 Slide ID: slide_32
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_128
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_129
# Inserting title: From Beast to Book into SLIDES_API1244585020_128
# 📝 Processed content preview: • Parchment is one of the largest curated tissue archives in history.
# • Non-invasive methods unlock ...
#
# 🔍 Slide ID: slide_33
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_132
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_133
# Inserting title: The Path Forward into SLIDES_API1244585020_132
# 📝 Processed content preview: • Integrate biomolecular data with codicology and palaeography.
# • Pursue ambitious "crazy ideas" to ...
#
# 🔍 Slide ID: slide_34
#  - Found placeholder: Type=TITLE, Object ID=SLIDES_API1244585020_136
#  - Found placeholder: Type=BODY, Object ID=SLIDES_API1244585020_137
# Inserting title: Thank You into SLIDES_API1244585020_136
# 📝 Processed content preview: • matthew@palaeome.org
# • @matthewcollins.bsky.social
# • For a sampling kit, please email me....
# 📝 Inserting clean text content...
# ✅ Presentation created: https://docs.google.com/presentation/d/1rfbOcXUq7n5EQAXZSbErV_IGAzZylUTkmCIUZHmLDRY
#
# 🎉 SUCCESS! Presentation created successfully!
# 📎 Direct link: https://docs.google.com/presentation/d/1rfbOcXUq7n5EQAXZSbErV_IGAzZylUTkmCIUZHmLDRY
